# %% [markdown]
# <a href="https://colab.research.google.com/github/Lubraca/Supervised_ML_Models/blob/Feature_Load_EDA/Classification/Loan_Default_Prediction/Project_01/ETL_Project_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Create the target directory (We'll use a simpler, consistent location)
# !mkdir -p /usr/local/vscode-cli

# %%
# 2. Download and extract the latest stable VS Code CLI
# !wget -O code_cli.tar.gz https://update.code.visualstudio.com/latest/cli-linux-x64/stable
# !tar -xzf code_cli.tar.gz

# 3. Find the executable (named 'code') and move it into the consistent directory
# !find . -name 'code' -type f -exec mv {} /usr/local/vscode-cli/ \;

# Clean up the downloaded archive
# !rm code_cli.tar.gz
# Out:
# --2025-11-11 18:38:05--  https://update.code.visualstudio.com/latest/cli-linux-x64/stable
# Resolving update.code.visualstudio.com (update.code.visualstudio.com)... 13.107.246.40, 13.107.213.40, 2620:1ec:bdf::40, ...
# Connecting to update.code.visualstudio.com (update.code.visualstudio.com)|13.107.246.40|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://vscode.download.prss.microsoft.com/dbazure/download/stable/7d842fb85a0275a4a8e4d7e040d2625abbf7f084/vscode_cli_linux_x64_cli.tar.gz [following]
# --2025-11-11 18:38:05--  https://vscode.download.prss.microsoft.com/dbazure/download/stable/7d842fb85a0275a4a8e4d7e040d2625abbf7f084/vscode_cli_linux_x64_cli.tar.gz
# Resolving vscode.download.prss.microsoft.com (vscode.download.prss.microsoft.com)... 199.232.210.172, 199.232.214.172, 2a04:4e42:4e::684, ...
# Connecting to vscode.download.prss.microsoft.com (vscode.download.prss.microsoft.com)|199.232.210.172|:443... connected.
# ...

# %%
# 3. Check if the command is now available and working
# !/usr/local/vscode-cli/code --version
# Out:
# code 1.105.1 (commit 7d842fb85a0275a4a8e4d7e040d2625abbf7f084)

# %%
# Step 3A: Log in explicitly with the Microsoft provider
# !/usr/local/vscode-cli/code tunnel user login --provider microsoft
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FEEVS2CJE to authenticate.

# %%
# Step 3B: Start the tunnel using the existing login token
# !/usr/local/vscode-cli/code tunnel
# Out:
# *
# * Visual Studio Code Server
# *
# * By using the software, you agree to
# * the Visual Studio Code Server License Terms (https://aka.ms/vscode-server-license) and
# * the Microsoft Privacy Statement (https://privacy.microsoft.com/en-US/privacystatement).
# *
#
# Open this link in your browser https://vscode.dev/tunnel/colab_vm/content
#
# [2025-11-11 18:39:02] info [tunnels::connections::relay_tunnel_host] Opened new client on channel 2
# [2025-11-11 18:39:02] info [russh::server] wrote id
# [2025-11-11 18:39:02] info [russh::server] read other id
# [2025-11-11 18:39:02] info [russh::server] session is running
# [2025-11-11 18:39:03] info [rpc.0] Checking /root/.vscode/cli/servers/Stable-7d842fb85a0275a4a8e4d7e040d2625abbf7f084/log.txt and /root/.vscode/cli/servers/Stable-7d842fb85a0275a4a8e4d7e040d2625abbf7f084/pid.txt for a running server...
# [2025-11-11 18:39:03] info [rpc.0] Starting server...
# [2025-11-11 18:39:03] info [rpc.0] Server started
# ...
